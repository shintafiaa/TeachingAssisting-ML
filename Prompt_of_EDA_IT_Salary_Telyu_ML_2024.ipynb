# %% [markdown]
# <a href="https://colab.research.google.com/github/shintafiaa/TeachingAssisting-ML/blob/main/Prompt_of_EDA_IT_Salary_Telyu_ML_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas:
#
# 1. Selesaikan proses Exploratory Data Analysis untuk seluruh features!
# 2. Tuliskan insight setiap output/keluaran!

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk connect google drive ke google colab!

# %%
# Out:
# Mounted at /content/drive

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk read dataset as dataframe dengan path "/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv"

# %%
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
df.head(7)
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
# 5  24/11/2020 11:15:53  32.0   Male  Berlin              DevOps
# 6  24/11/2020 11:16:35  37.0   Male  Berlin  Frontend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
# ...

# %%
df.tail(9)
# Out:
#                 Timestamp   Age Gender         City  \
# 1244  16/01/2021 22:23:04  32.0   Male       Munich
# 1245  17/01/2021 13:22:23  28.0   Male       Berlin
# 1246  18/01/2021 09:51:30  38.0   Male       Berlin
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1244                       Software Engineer                        10
# 1245                      Frontend Developer                         5
# 1246                     Head of Engineering                        18
# 1247                       Software Engineer                         7
# 1248                       Backend Developer                         9
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilkan informasi ringkas dari dataframe!

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# ChatGPT Prompt: Beri petunjuk untuk melakukan Exploratory Data Analysis!

# %% [markdown]
# Berikut adalah beberapa langkah yang dapat Anda ambil untuk melakukan Exploratory Data Analysis (EDA) dengan DataFrame yang Anda miliki:
#
# 1. **Periksa Data Awal:**
#    - Anda telah mendapatkan informasi ringkas tentang DataFrame dari output yang Anda berikan. Periksa kolom-kolom tersebut untuk memahami jenis data apa yang Anda miliki.
#
# 2. **Periksa Tipe Data:**
#    - Periksa tipe data dari setiap kolom. Pastikan bahwa tipe data yang diparse sesuai dengan yang Anda harapkan. Misalnya, pastikan bahwa kolom "Age" yang seharusnya berisi angka memiliki tipe data numerik, bukan objek.
#
# 3. **Periksa Data yang Hilang:**
#    - Periksa apakah ada nilai yang hilang (null) dalam DataFrame. Hal ini penting karena data yang hilang dapat memengaruhi analisis Anda.
#
# 4. **Statistik Deskriptif:**
#    - Hitung statistik deskriptif untuk kolom-kolom numerik seperti mean, median, dan standar deviasi. Ini akan memberikan pemahaman awal tentang distribusi data.
#
# 5. **Visualisasi Data:**
#    - Buat visualisasi data untuk masing-masing kolom, terutama kolom-kolom kategorikal. Anda dapat menggunakan histogram, box plot, bar plot, dan visualisasi lainnya untuk memahami distribusi dan pola data.
#
# 6. **Analisis Korelasi:**
#    - Lakukan analisis korelasi antara kolom-kolom numerik untuk melihat hubungan antara mereka. Anda dapat menggunakan heatmap korelasi untuk memvisualisasikan ini.
#
# 7. **Analisis Variabel Kategorikal:**
#    - Untuk kolom-kolom kategorikal, lakukan analisis untuk melihat frekuensi masing-masing kategori dan bagaimana mereka terkait dengan variabel lain.
#
# 8. **Segmentasi Data:**
#    - Jika memungkinkan, lakukan segmentasi data berdasarkan kolom-kolom tertentu (misalnya, posisi pekerjaan, teknologi utama, atau ukuran perusahaan) dan lakukan analisis lebih lanjut untuk setiap segmen.
#
# 9. **Identifikasi Outliers:**
#    - Periksa apakah ada outliers dalam data. Outliers dapat mempengaruhi hasil analisis Anda dan mungkin perlu ditangani secara khusus.
#
# 10. **Analisis Time Series (Jika Ada):**
#     - Jika data memiliki dimensi waktu, lakukan analisis time series untuk memahami pola dan tren seiring waktu.
#
# 11. **Uji Hipotesis (Jika Diperlukan):**
#     - Jika Anda memiliki pertanyaan tertentu atau hipotesis yang ingin Anda uji, lakukan uji hipotesis untuk mendapatkan pemahaman yang lebih dalam tentang data Anda.
#
# Setelah melalui langkah-langkah tersebut, Anda akan mendapatkan pemahaman yang lebih baik tentang data yang Anda miliki, yang akan membantu Anda dalam pengambilan keputusan yang lebih baik atau merumuskan pertanyaan untuk analisis lebih lanjut.

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk mendapatkan summary statistical dari dataframe

# %%
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk melihat 5 baris teratas dari fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", "Сontract duration", "Company size"

# %%
# Out:
#   Total years of experience Years of experience in Germany  \
# 0                         5                              3
# 1                         7                              4
# 2                        12                              6
# 3                         4                              1
# 4                        17                              6
#
#   Yearly bonus + stocks in EUR  \
# 0                         5000
# 1                          NaN
# 2                       120000
# 3                          NaN
# 4                          NaN
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days   Сontract duration Company size
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk mengubah fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", bertipe data numerik!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Total experience  Experience in Germany  \
# count  1226.000000       1230.000000            1194.000000
# mean     32.509788          9.078130               3.757956
# std       5.663804         11.901317               3.656551
# min      20.000000          0.000000               0.000000
# 25%      29.000000          5.000000               1.000000
# 50%      32.000000          8.000000               3.000000
# 75%      35.000000         12.000000               5.000000
# max      69.000000        383.000000              30.000000
#
#        Yearly brutto salary  Yearly bonus and stocks  \
# count          1.253000e+03             8.230000e+02
# mean           8.027904e+07             6.096870e+06
# std            2.825061e+09             1.742883e+08
# min            1.000100e+04             0.000000e+00
# 25%            5.880000e+04             0.000000e+00
# 50%            7.000000e+04             5.000000e+03
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk memperbarui nama-nama fitur berikut:
#
# * Total years of experience -> Total experience
#
# * Years of experience in Germany -> Experience in Germany
#
# * Your main technology / programming language -> Main programming language
#
# * Other technologies/programming languages you use often -> Other programming languages
#
# * Yearly brutto salary (without bonus and stocks) in EUR -> Yearly brutto salary
#
# * Yearly bonus + stocks in EUR -> Yearly bonus and stocks
#
# * Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country -> Previous yearly brutto salary
#
# * Annual bonus+stocks one year ago. Only answer if staying in same country -> Previous yearly bonus and stocks
#
# * Number of vacation days -> Vacation days
#
# * Main language at work -> Main work language
#
# * Have you lost your job due to the coronavirus outbreak? -> Lost job due to COVID-19
#
# * Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week -> Kurzarbeit hours per week
#
# * Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR -> Additional monetary support in 2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt: Beri baris untuk menampilkan baris yang memiliki null value

# %%
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
#
#                                    Position   Total experience  \
# 0                          Software Engineer               5.0
# 1                          Backend Developer               7.0
# 2                          Software Engineer              12.0
# 3                         Frontend Developer               4.0
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk mengisi baris dari fitur "Kurzarbeit hours per week" yang memiliki null value dengan nilai "0"

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilkan pie diagram chart untk fitur Age dengan min 20, max 69

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilkan baris data yang memiliki Age '51-60', '60+'

# %%
# Out:
#                 Timestamp   Age Gender        City           Position   \
# 23    24/11/2020 11:23:11  59.0   Male      Berlin   Backend Developer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt   Software Engineer
# 233   24/11/2020 13:54:47  53.0   Male   Stuttgart  Frontend Developer
# 403   24/11/2020 19:48:24  50.0   Male      Berlin   Software Engineer
# 673   25/11/2020 18:56:02  51.0   Male      Berlin   Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano              Sales
# 1159  14/12/2020 08:55:24  56.0   Male      Munich   Software Engineer
# 1182  20/12/2020 01:48:34  54.0   Male      Munich   Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male   Stuttgart   Software Engineer
#
#       Total experience  Experience in Germany Seniority level  \
# 23                30.0                   30.0          Senior
# 232                9.0                    9.0          Senior
# 233               15.0                   15.0          Senior
# ...
